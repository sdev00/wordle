# %%
# %load_ext line_profiler

# %%
from english_words import english_words_set
from wordfreq import word_frequency
from collections import Counter
import numpy as np
import random
ALPHABET = 'abcdefghijklmnopqrstuvwxyz'
WORD_LEN = 5
MIN_FREQ = 5e-7

# %%
def load_words(path):
    words = []
    with open(path) as file:
        for line in file:
            word = line.split('\n')[0]
            words.append(word)
    return(words)

wordles = load_words('wordles_shuffled')
print(random.sample(wordles, 10))
accepted_words = load_words('words')
accepted_words.extend(wordles)
accepted_words.sort()
print(random.sample(accepted_words, 10))
# Out:
# ['drunk', 'barge', 'snare', 'grown', 'erase', 'enjoy', 'upset', 'pixel', 'mange', 'fuzzy']
# ['shops', 'punch', 'lemes', 'welch', 'bevue', 'baggy', 'gebur', 'neums', 'bowel', 'swore']

# %%
RESTRICT = lambda word: word.islower() and word.isalpha() and len(word) == WORD_LEN \
    and word_frequency(word, 'en') >= MIN_FREQ

def removeProperNouns(words):
    result = words.copy()
    for word in words:
        if word[0].isupper():
            result.remove(word)
    return result

print(random.sample(removeProperNouns(english_words_set), 10))

def restrictWordLength(words, length):
    result = words.copy()
    for word in words:
        if len(word) != length:
            result.remove(word)
    return result

print(random.sample(restrictWordLength(english_words_set, 5), 10))

def restrictSet(words, key):
    result = words.copy()
    for word in words:
        if not key(word):
            result.remove(word)
    return result

words = restrictSet(english_words_set, RESTRICT)
for word in random.sample(words, 15):
    print(f'{word}: {word_frequency(word, "en")}')
# Out:
# ['toddy', 'giant', 'fail', 'nuclear', 'crocodile', 'bacterial', 'deepen', 'sixtyfold', 'churchwoman', 'beverage']
# ['probe', 'torso', 'idyll', 'Gregg', 'alert', 'endow', 'aster', 'Dhabi', 'flesh', 'sleet']
# genie: 2.57e-06
# hence: 2.4e-05
# juror: 1.35e-06
# supra: 1.2e-06
# bound: 2.88e-05
# thing: 0.000525
# neath: 6.92e-07
# stork: 7.59e-07
# glory: 2.29e-05
# fiend: 1.26e-06
# booty: 3.89e-06
# anode: 7.24e-07
# crane: 8.32e-06
# handy: 9.33e-06
# brake: 8.91e-06

# %%
WEIGHTS = {word:word_frequency(word, 'en') for word in words}
def getLetterFrequencies(words, weighted=True):
    freqs, overall = [{letter: 0 for letter in ALPHABET} for i in range(5)], {letter: 0 for letter in ALPHABET}
    for word in words:
        weight = WEIGHTS[word] if weighted else 1
        for index, letter in enumerate(word):
            freqs[index][letter] += weight
            overall[letter] += weight
            
    return freqs, overall

# %%
ORDINALS = ['1st', '2nd', '3rd', '4th', '5th', '6th']
def printMaxIndexFreqs(freqs, overall):
    letters = sorted(ALPHABET, reverse=True, key=lambda letter: overall[letter])
    print(f'Overall frequency order:\t{"|".join(letters)}')
    
    for index, dic in enumerate(freqs):
        letters = sorted(ALPHABET, reverse=True, key=lambda letter: dic[letter] if letter in dic else 0)
        print(f'Frequency order for {ORDINALS[index]} letter:\t{"|".join(letters)}')

# %%
# print('Weighted by word frequency')
# freqs, overall = getFrequencies(words, weighted=True)
# printMaxIndexFreqs(freqs, overall)

print('Unweighted')
freqs, overall = getLetterFrequencies(wordles, weighted=False)
printMaxIndexFreqs(freqs, overall)
# Out:
# Unweighted
# Overall frequency order:	e|a|r|o|t|l|i|s|n|c|u|y|d|h|p|m|g|b|f|k|w|v|z|x|q|j
# Frequency order for 1st letter:	s|c|b|t|p|a|f|g|d|m|r|l|w|e|h|v|o|n|i|u|q|j|k|y|z|x
# Frequency order for 2nd letter:	a|o|r|e|i|l|u|h|n|t|p|w|c|m|y|d|b|s|v|x|g|k|f|q|j|z
# Frequency order for 3rd letter:	a|i|o|e|u|r|n|l|t|s|d|g|m|p|b|c|v|y|w|f|k|x|z|h|j|q
# Frequency order for 4th letter:	e|n|s|a|l|i|c|r|t|o|u|g|d|m|k|p|v|f|h|w|b|z|x|y|j|q
# Frequency order for 5th letter:	e|y|t|r|l|h|n|d|k|a|o|p|m|g|s|c|f|w|b|i|x|z|u|j|q|v

# %%
def satisfies(word, exact, contains, absent):
    word = list(word)
    for index, letter in exact:
        if word[index] != letter:
            return False
        word[index] = '_'
        
    for index, letter in contains:
        if (word[index] == letter or letter not in word):
            return False
        word[word.index(letter)] = '_'
        
    for index, letter in absent:
        if letter in word:
            return False
        
    return True

def score(words, guess, word, print_possible=False):
    exact, contains, absent = [], [], []
    if guess not in accepted_words:
        if print_possible:
            print(f'Warning: "{guess}" not in word list')
        
    counts = Counter(word)
    for index, letter in enumerate(guess):
        if word[index] == letter:
            exact.append((index, letter))
            counts[letter] -= 1
        elif letter in word and counts[letter] > 0:
            contains.append((index, letter))
            counts[letter] -= 1
        else:
            absent.append((index, letter))
            
    possible = set()
    for word in words:
        if satisfies(word, exact, contains, absent):
            possible.add(word)
    
    score = len(words) - len(possible)
    if print_possible:
        print(f'Green letters: {exact}')
        print(f'Yellow letters: {contains}')
        print(f'Gray letters: {absent}')
        print(f'All possible words ({len(possible)}): {possible}')
        print(f'Score ({len(words)}-{len(possible)})): {score}')
        
    return score

score(wordles, 'bread', 'bears', print_possible=True)
# Out:
# Green letters: [(0, 'b')]
# Yellow letters: [(1, 'r'), (2, 'e'), (3, 'a')]
# Gray letters: [(4, 'd')]
# All possible words (4): {'baker', 'blare', 'baler', 'barge'}
# Score (2315-4)): 2311
# 2311

# %%
def computeAverageScore(words, guess):
    sc = 0
    for word in words:
        sc += score(words, guess, word)
        
    return np.round(sc/len(words), 3)

# jank way of testing if saved_scores is a variable
try:
    print('rates' in saved_scores)
except:
    saved_scores = {}

# %%
def prof():
    computeAverageScore(wordles, 'rates')

# %lprun -f satisfies prof()
# Out:
# UsageError: Line magic function `%lprun` not found.

# %%
# %%time
computeAverageScore(wordles, 'raise')

# %%
# %%time
def scoreGuesses(words, saved_scores, *args, list_all=False):
    best = 0
    for guess in args:
        if guess not in saved_scores:
            sc = computeAverageScore(words, guess)
            saved_scores[guess] = sc
        
        if saved_scores[guess] > best:
            best = saved_scores[guess]
            print(f'New best! Average score for {guess}: {saved_scores[guess]}')
        elif list_all:
            print(f'Average score for {guess}: {saved_scores[guess]}')

scoreGuesses(wordles, saved_scores,
    'llama', 'trace', 'cares', 'shear', 'thine', 'tears', 'stare', 
    'anode', 'caret', 'crane', 'crate', 'canoe', 'chart', 'raise', 'arise',
     list_all=True)
# Out:
# New best! Average score for llama: 1875.945
# New best! Average score for trace: 2240.98
# Average score for cares: 2233.197
# Average score for shear: 2222.255
# Average score for thine: 2196.207
# Average score for tears: 2239.552
# New best! Average score for stare: 2243.705
# Average score for anode: 2210.205
# Average score for caret: 2239.4
# Average score for crane: 2236.258
# Average score for crate: 2242.1
# Average score for canoe: 2228.168
# Average score for chart: 2174.498
# New best! Average score for raise: 2253.999
# Average score for arise: 2251.274
# Wall time: 3.04 s

# %%
most_common = []
for i in range(27):
    most_common.append(set(list(sorted(ALPHABET, reverse=True, key=lambda letter: overall[letter]))[:i]))

print(most_common[8])
# Out:
# {'e', 't', 'a', 'o', 'r', 'i', 'l', 's'}

# %%
# %%time
accepted = [word for word in accepted_words if 
            (len(set(word)) == len(word) and 
             sum((1 if letter in most_common[3] else 0) for letter in word) >= 2 and
             sum((1 if letter in most_common[7] else 0) for letter in word) >= 4)]

print(f'Scoring list of {len(accepted)} words')
scoreGuesses(wordles, saved_scores, *accepted, list_all=True)
# Out:
# Scoring list of 587 words
# New best! Average score for abler: 2207.016
# New best! Average score for ablet: 2207.399
# New best! Average score for abore: 2217.535
# Average score for abort: 2189.879
# Average score for actor: 2206.383
# New best! Average score for adore: 2225.957
# New best! Average score for aeros: 2239.798
# New best! Average score for aesir: 2245.117
# Average score for afire: 2215.794
# Average score for afore: 2215.746
# Average score for afrit: 2178.626
# Average score for after: 2204.993
# Average score for agile: 2208.926
# Average score for aglet: 2213.493
# Average score for aider: 2221.125
# Average score for aiery: 2227.965
# Average score for ailed: 2213.014
# Average score for aimer: 2218.682
# Average score for aired: 2224.975
# Average score for airth: 2202.855
# Average score for airts: 2220.663
# Average score for aisle: 2238.811
# Average score for aiver: 2199.006
# Average score for aizle: 2183.362
# Average score for alder: 2220.688
# Average score for aleft: 2190.658
# Average score for alert: 2243.401
# Average score for algor: 2194.43
# Average score for alien: 2231.403
# Average score for alike: 2204.441
# Average score for aline: 2234.384
# Average score for alive: 2193.846
# Average score for alkie: 2201.639
# Average score for aloed: 2219.171
# Average score for aloes: 2237.644
# Average score for alone: 2237.837
# Average score for alowe: 2204.282
# Average score for alter: 2245.008
# Average score for alure: 2239.323
# Average score for amole: 2213.673
# Average score for amort: 2195.539
# Average score for amrit: 2192.949
# Average score for anile: 2232.798
# Average score for anole: 2236.319
# Average score for antre: 2241.057
# Average score for apert: 2217.553
# Average score for aport: 2202.377
# Average score for apter: 2219.105
# Average score for areic: 2227.551
# Average score for arets: 2236.84
# Average score for argil: 2193.847
# Average score for argle: 2225.189
# Average score for argol: 2195.95
# Average score for argot: 2198.409
# New best! Average score for ariel: 2249.712
# Average score for arils: 2228.783
# Average score for ariot: 2229.314
# New best! Average score for arise: 2251.274
# Average score for arled: 2224.772
# Average score for arles: 2245.109
# Average score for armet: 2224.834
# Average score for armil: 2196.263
# Average score for aroid: 2195.962
# Average score for arose: 2248.979
# Average score for artel: 2247.504
# Average score for artic: 2206.129
# Average score for artis: 2220.997
# Average score for aster: 2236.915
# Average score for astir: 2218.433
# Average score for atoke: 2209.234
# Average score for atone: 2236.041
# Average score for atrip: 2193.294
# Average score for aurei: 2226.873
# Average score for avert: 2195.979
# Average score for aweto: 2184.924
# Average score for axile: 2183.072
# Average score for axite: 2184.683
# Average score for ayrie: 2236.012
# Average score for azole: 2185.986
# Average score for azote: 2188.81
# Average score for baler: 2213.117
# Average score for belar: 2207.706
# Average score for birle: 2210.534
# Average score for biter: 2197.887
# Average score for blaer: 2215.872
# Average score for blare: 2220.605
# Average score for blart: 2196.75
# Average score for blate: 2215.514
# Average score for blear: 2207.127
# Average score for bleat: 2196.662
# Average score for blert: 2202.116
# Average score for blore: 2207.767
# Average score for boart: 2203.136
# Average score for bolar: 2188.153
# Average score for boral: 2185.932
# Average score for borel: 2200.21
# Average score for brail: 2198.444
# Average score for caret: 2239.4
# Average score for carle: 2240.32
# Average score for carol: 2216.087
# Average score for carte: 2241.484
# Average score for cater: 2234.18
# Average score for ceorl: 2223.06
# Average score for ceria: 2226.638
# Average score for citer: 2218.928
# Average score for claro: 2211.326
# Average score for clart: 2218.212
# Average score for clear: 2226.721
# Average score for cleat: 2218.232
# Average score for coate: 2240.493
# Average score for coral: 2210.889
# Average score for coria: 2200.878
# Average score for crate: 2242.1
# Average score for dater: 2226.792
# Average score for deair: 2229.661
# Average score for dealt: 2223.662
# Average score for delta: 2209.699
# Average score for derat: 2225.632
# Average score for doter: 2207.521
# Average score for drail: 2209.497
# Average score for drole: 2221.153
# Average score for earls: 2236.072
# Average score for early: 2218.412
# Average score for earnt: 2238.235
# Average score for earst: 2238.188
# Average score for earth: 2217.705
# Average score for eclat: 2207.864
# Average score for elain: 2221.712
# Average score for eliad: 2199.07
# Average score for email: 2195.652
# Average score for enrol: 2216.006
# Average score for entia: 2204.521
# Average score for eorls: 2222.863
# Average score for erbia: 2199.709
# Average score for ergot: 2194.505
# Average score for erica: 2220.737
# Average score for ervil: 2173.959
# Average score for estro: 2208.435
# Average score for ethal: 2193.017
# Average score for exalt: 2166.852
# Average score for extra: 2162.69
# Average score for farle: 2219.926
# Average score for feart: 2213.647
# Average score for feral: 2201.32
# Average score for feria: 2202.334
# Average score for fetal: 2189.676
# Average score for fetor: 2190.467
# Average score for filar: 2180.872
# Average score for filer: 2188.098
# Average score for flair: 2189.991
# Average score for flare: 2216.834
# Average score for flier: 2191.952
# Average score for flora: 2176.2
# Average score for forel: 2196.594
# Average score for forte: 2202.141
# Average score for frail: 2190.807
# Average score for frate: 2221.653
# Average score for frati: 2183.301
# Average score for freit: 2189.717
# Average score for gater: 2223.026
# Average score for gator: 2203.614
# Average score for glair: 2204.447
# Average score for glare: 2226.451
# Average score for goier: 2208.838
# Average score for goral: 2195.468
# Average score for grail: 2203.559
# Average score for grate: 2230.419
# Average score for great: 2218.428
# Average score for groat: 2204.21
# Average score for haler: 2230.098
# Average score for haole: 2235.051
# Average score for hater: 2227.047
# Average score for heart: 2225.857
# Average score for hilar: 2209.976
# Average score for horal: 2207.179
# Average score for ideal: 2194.431
# Average score for idler: 2198.155
# Average score for iftar: 2173.426
# Average score for ileac: 2205.823
# Average score for inert: 2217.057
# Average score for inter: 2217.302
# Average score for intra: 2202.828
# Average score for irade: 2229.571
# Average score for irate: 2251.221
# Average score for irone: 2231.397
# Average score for ither: 2201.617
# Average score for ixora: 2136.092
# Average score for kiore: 2211.425
# Average score for kiter: 2195.09
# Average score for korai: 2177.59
# Average score for korat: 2192.696
# Average score for krait: 2196.327
# Average score for labor: 2190.763
# Average score for lacer: 2229.444
# Average score for lacet: 2231.279
# Average score for lader: 2222.246
# Average score for laers: 2236.124
# Average score for laevo: 2184.175
# Average score for lager: 2218.185
# Average score for laird: 2207.34
# Average score for lairs: 2226.855
# Average score for lairy: 2209.755
# Average score for laker: 2208.682
# Average score for lamer: 2216.879
# Average score for lares: 2243.255
# Average score for large: 2224.831
# Average score for largo: 2193.595
# Average score for laris: 2225.724
# Average score for larnt: 2228.967
# Average score for laser: 2242.878
# Average score for lated: 2220.806
# Average score for laten: 2236.422
# Average score for later: 2244.777
# Average score for latex: 2182.626
# Average score for lathe: 2223.603
# Average score for latke: 2209.392
# Average score for laver: 2197.059
# Average score for lawer: 2206.246
# Average score for laxer: 2189.612
# Average score for layer: 2227.172
# Average score for leant: 2237.74
# Average score for leapt: 2218.333
# Average score for learn: 2238.359
# Average score for lears: 2238.171
# Average score for leary: 2226.022
# Average score for least: 2236.81
# Average score for leats: 2232.384
# Average score for leirs: 2229.495
# Average score for lepra: 2212.485
# Average score for lepta: 2204.695
# Average score for liane: 2239.726
# Average score for liard: 2205.316
# Average score for liars: 2224.448
# Average score for liart: 2233.748
# Average score for liber: 2195.908
# Average score for libra: 2178.34
# Average score for lidar: 2199.386
# Average score for liers: 2225.574
# Average score for lifer: 2185.955
# Average score for liger: 2198.821
# Average score for liker: 2191.399
# Average score for liner: 2222.524
# Average score for liras: 2222.763
# Average score for liter: 2231.513
# Average score for litre: 2238.677
# Average score for liver: 2176.401
# Average score for livre: 2187.774
# Average score for loave: 2204.935
# Average score for lobar: 2186.864
# Average score for loner: 2225.953
# Average score for loper: 2205.682
# Average score for loran: 2219.272
# Average score for lores: 2231.762
# Average score for loser: 2231.836
# Average score for loure: 2228.878
# Average score for lover: 2177.748
# Average score for lower: 2185.775
# Average score for lutea: 2220.581
# Average score for luter: 2217.995
# Average score for lyart: 2209.43
# Average score for maerl: 2216.518
# Average score for maile: 2223.749
# Average score for maire: 2235.025
# Average score for marle: 2228.568
# Average score for mater: 2220.82
# Average score for meril: 2207.092
# Average score for merit: 2209.089
# Average score for metal: 2203.114
# Average score for metro: 2199.21
# Average score for miler: 2203.573
# Average score for miter: 2203.65
# Average score for mitre: 2213.079
# Average score for moira: 2188.151
# Average score for moire: 2220.095
# Average score for molar: 2196.064
# Average score for morae: 2224.488
# Average score for moral: 2193.866
# Average score for morat: 2200.517
# Average score for morel: 2208.667
# Average score for moria: 2179.877
# Average score for neral: 2234.407
# Average score for nerol: 2226.425
# Average score for niter: 2220.707
# Average score for nitre: 2228.177
# Average score for noria: 2205.23
# Average score for noter: 2223.279
# Average score for oaker: 2210.138
# Average score for oared: 2224.943
# Average score for oaten: 2233.46
# Average score for oater: 2243.755
# Average score for ocrea: 2220.191
# Average score for ofter: 2181.286
# Average score for ogler: 2195.057
# Average score for oiler: 2230.941
# Average score for older: 2203.969
# Average score for olpae: 2210.456
# Average score for opera: 2205.685
# Average score for opter: 2198.564
# Average score for orals: 2229.621
# Average score for orant: 2229.156
# Average score for orate: 2251.109
# Average score for oread: 2213.259
# Average score for orgia: 2174.119
# Average score for oriel: 2238.232
# Average score for orixa: 2143.825
# Average score for orles: 2231.795
# Average score for orval: 2166.926
# Average score for osier: 2226.102
# Average score for otary: 2207.667
# Average score for other: 2200.016
# Average score for ourie: 2224.359
# Average score for outer: 2214.085
# Average score for outre: 2220.673
# Average score for ovate: 2199.684
# Average score for overt: 2173.593
# Average score for owler: 2179.241
# Average score for owrie: 2193.656
# Average score for oxter: 2157.028
# Average score for paire: 2238.13
# Average score for paler: 2224.183
# Average score for palet: 2224.878
# Average score for pareo: 2225.469
# Average score for parle: 2232.431
# Average score for parol: 2206.219
# Average score for parti: 2199.7
# Average score for pater: 2225.271
# Average score for pearl: 2223.892
# Average score for peart: 2228.317
# Average score for pelta: 2207.128
# Average score for perai: 2217.452
# Average score for peril: 2209.868
# Average score for petal: 2209.122
# Average score for petar: 2221.701
# Average score for petri: 2200.811
# Average score for piert: 2205.581
# Average score for pieta: 2201.643
# Average score for pilae: 2216.028
# Average score for pilar: 2201.492
# Average score for pilea: 2208.53
# Average score for piler: 2206.888
# Average score for plate: 2225.709
# Average score for pleat: 2208.683
# Average score for plier: 2211.053
# Average score for polar: 2203.578
# Average score for poler: 2209.037
# Average score for porae: 2229.729
# Average score for poral: 2201.039
# Average score for porta: 2196.063
# Average score for potae: 2225.527
# Average score for prate: 2233.5
# Average score for prial: 2202.998
# Average score for prole: 2222.352
# Average score for radio: 2196.568
# New best! Average score for raile: 2253.669
# Average score for rails: 2227.204
# Average score for raine: 2247.944
# New best! Average score for raise: 2253.999
# Average score for raits: 2225.727
# Average score for rales: 2242.198
# Average score for ramet: 2224.28
# Average score for ramie: 2228.831
# Average score for rated: 2226.336
# Average score for ratel: 2245.157
# Average score for rates: 2241.673
# Average score for rathe: 2230.218
# Average score for ratio: 2222.996
# Average score for ratos: 2222.956
# Average score for ravel: 2197.576
# Average score for rayle: 2233.018
# Average score for react: 2235.17
# Average score for reais: 2243.389
# Average score for realm: 2217.516
# Average score for realo: 2245.052
# Average score for reals: 2240.06
# Average score for reast: 2243.235
# Average score for rebit: 2196.968
# Average score for recal: 2222.623
# Average score for recit: 2216.201
# Average score for recta: 2223.887
# Average score for recti: 2209.318
# Average score for recto: 2212.181
# Average score for redia: 2211.18
# Average score for refit: 2187.508
# Average score for regal: 2208.302
# Average score for reist: 2232.001
# Average score for relax: 2178.965
# Average score for relay: 2217.995
# Average score for relic: 2211.173
# Average score for relit: 2232.422
# Average score for remit: 2203.913
# Average score for renal: 2233.842
# Average score for reoil: 2237.99
# Average score for repla: 2213.486
# Average score for repot: 2208.904
# Average score for resat: 2238.968
# Average score for resit: 2227.992
# Average score for resto: 2224.439
# Average score for retag: 2213.033
# Average score for retax: 2181.667
# Average score for retia: 2236.452
# Average score for retox: 2163.535
# Average score for rials: 2226.079
# Average score for riant: 2226.078
# Average score for riels: 2226.509
# Average score for rifle: 2196.443
# Average score for rifte: 2195.05
# Average score for riled: 2205.395
# Average score for riles: 2230.522
# Average score for riley: 2212.84
# Average score for rimae: 2224.878
# Average score for rioja: 2147.446
# Average score for rites: 2227.205
# Average score for rival: 2163.738
# Average score for rivel: 2178.32
# Average score for rivet: 2182.102
# Average score for riyal: 2199.583
# Average score for roast: 2231.644
# New best! Average score for roate: 2254.575
# Average score for roble: 2205.344
# Average score for rolag: 2190.275
# Average score for roles: 2231.279
# Average score for romal: 2189.36
# Average score for ronte: 2233.336
# Average score for roset: 2232.568
# Average score for rotal: 2226.255
# Average score for rotan: 2217.543
# Average score for rotas: 2220.07
# Average score for roted: 2207.891
# Average score for rotes: 2228.537
# Average score for roule: 2229.835
# Average score for route: 2227.899
# Average score for rowel: 2189.159
# Average score for rowie: 2202.342
# Average score for royal: 2203.108
# Average score for rozet: 2174.997
# Average score for salet: 2243.728
# Average score for serai: 2242.079
# Average score for seral: 2241.921
# Average score for setal: 2232.622
# Average score for siler: 2236.332
# Average score for sitar: 2229.218
# Average score for slart: 2229.005
# Average score for slate: 2243.427
# Average score for slier: 2239.051
# Average score for soare: 2252.699
# Average score for solar: 2232.167
# Average score for soler: 2236.745
# Average score for soral: 2229.138
# Average score for sorel: 2238.916
# Average score for sorta: 2221.143
# Average score for stair: 2227.756
# Average score for stale: 2239.396
# Average score for stare: 2243.705
# Average score for steal: 2222.14
# Average score for stear: 2236.05
# Average score for stela: 2221.255
# Average score for stire: 2233.67
# Average score for stoae: 2240.104
# Average score for store: 2233.781
# Average score for strae: 2243.154
# Average score for stria: 2214.456
# Average score for taber: 2217.698
# Average score for table: 2216.348
# Average score for tabor: 2196.782
# Average score for taels: 2230.214
# Average score for taker: 2215.211
# Average score for taler: 2247.263
# Average score for tales: 2238.839
# Average score for tamer: 2221.826
# Average score for taper: 2225.583
# Average score for tapir: 2206.977
# Average score for tardo: 2205.432
# Average score for tared: 2229.943
# Average score for tares: 2243.457
# Average score for targe: 2228.235
# Average score for taroc: 2213.992
# Average score for tarok: 2193.63
# Average score for taros: 2225.279
# Average score for tarsi: 2222.824
# Average score for taser: 2243.724
# Average score for taver: 2202.851
# Average score for tawer: 2211.117
# Average score for tawie: 2215.018
# Average score for taxer: 2193.426
# Average score for taxor: 2168.687
# Average score for teals: 2235.029
# Average score for tears: 2239.552
# Average score for teary: 2231.235
# Average score for telia: 2230.47
# Average score for tenia: 2221.976
# Average score for tenor: 2228.245
# Average score for tepal: 2210.427
# Average score for terai: 2239.857
# Average score for teras: 2237.792
# Average score for terga: 2212.004
# Average score for tesla: 2229.848
# Average score for thale: 2227.001
# Average score for their: 2208.182
# Average score for thrae: 2227.94
# Average score for throe: 2215.377
# Average score for tiars: 2223.978
# Average score for tiers: 2222.082
# Average score for tiger: 2202.187
# Average score for tiler: 2234.689
# Average score for timer: 2204.403
# Average score for tinea: 2227.229
# Average score for tired: 2211.213
# Average score for tires: 2230.614
# Average score for toaze: 2203.367
# Average score for toeas: 2230.02
# Average score for togae: 2220.197
# Average score for toker: 2196.857
# Average score for tolar: 2231.724
# Average score for toner: 2227.218
# Average score for toper: 2208.575
# Average score for torah: 2204.302
# Average score for toran: 2221.978
# Average score for toras: 2222.676
# Average score for tores: 2230.091
# Average score for torse: 2237.044
# Average score for tower: 2186.188
# Average score for toyer: 2216.796
# Average score for trace: 2240.98
# Average score for trade: 2234.068
# Average score for tragi: 2196.964
# Average score for traik: 2193.15
# Average score for trail: 2235.552
# Average score for train: 2226.231
# Average score for trape: 2232.33
# Average score for trave: 2212.505
# Average score for trawl: 2191.891
# Average score for tread: 2219.728
# Average score for trefa: 2199.629
# Average score for treif: 2186.777
# Average score for trema: 2211.059
# Average score for triac: 2212.638
# Average score for triad: 2205.715
# Average score for trial: 2232.058
# Average score for tribe: 2209.471
# Average score for trice: 2228.949
# Average score for tride: 2217.027
# Average score for tried: 2212.961
# Average score for tries: 2233.446
# Average score for trike: 2207.235
# Average score for trine: 2233.111
# Average score for tripe: 2217.164
# Average score for troad: 2205.942
# Average score for troak: 2190.481
# Average score for trode: 2216.522
# Average score for troke: 2207.054
# Average score for trona: 2218.876
# Average score for trone: 2236.179
# Average score for trope: 2217.671
# Average score for trove: 2193.439
# Average score for twier: 2189.919
# Average score for twire: 2198.672
# Average score for twoer: 2185.692
# Average score for tyler: 2216.289
# Average score for ultra: 2205.037
# Average score for uraei: 2233.578
# Average score for urali: 2215.81
# Average score for urate: 2242.17
# Average score for ureal: 2228.238
# Average score for urial: 2216.774
# Average score for urite: 2228.606
# Average score for uteri: 2205.335
# Average score for vaire: 2217.475
# Average score for valet: 2200.91
# Average score for valor: 2177.529
# Average score for velar: 2193.061
# Average score for viler: 2178.306
# Average score for viral: 2172.162
# Average score for vireo: 2180.356
# Average score for vitae: 2197.379
# Average score for volae: 2194.357
# Average score for volar: 2173.19
# Average score for voter: 2180.805
# Average score for waite: 2218.272
# Average score for waler: 2207.927
# Average score for walie: 2210.343
# Average score for water: 2210.474
# Average score for wrate: 2220.488
# Average score for write: 2202.582
# Average score for wrote: 2198.754
# Average score for yarto: 2206.159
# Average score for zaire: 2211.129
# Average score for zoeal: 2172.317
# Wall time: 12min 9s

# %%
scores_list = [(word, score) for word, score in saved_scores.items()]
scores_list.sort(key=lambda x: x[1], reverse=True)
scores_list[:20]
# Out:
# [('roate', 2254.575),
#  ('raise', 2253.999),
#  ('raile', 2253.669),
#  ('soare', 2252.699),
#  ('arise', 2251.274),
#  ('irate', 2251.221),
#  ('orate', 2251.109),
#  ('ariel', 2249.712),
#  ('arose', 2248.979),
#  ('raine', 2247.944),
#  ('artel', 2247.504),
#  ('taler', 2247.263),
#  ('ratel', 2245.157),
#  ('aesir', 2245.117),
#  ('arles', 2245.109),
#  ('realo', 2245.052),
#  ('alter', 2245.008),
#  ('later', 2244.777),
#  ('oater', 2243.755),
#  ('salet', 2243.728)]

# %%
def save_scores(path, scores_list):
    words = []
    with open(path, 'w') as file:
        for word, score in scores_list:
            file.write(f'{word} {score}\n')

save_scores('guess_scores_linear.txt', scores_list)

# %%
BASIC_RESTRICTION = lambda word: word.islower() and word.isalpha() and len(word) == WORD_LEN
RESULTS_RESTRICTION = lambda word: BASIC_RESTRICTION(word) and sum((1 if letter in 'eca' else 0) for letter in word) == 5
GUESS_RESTRICTION = lambda word: BASIC_RESTRICTION(word) and word in accepted_words

# %%
# e = exact, c = contains, a = absent
def solver(wordles, accepted_words):
    words = accepted_words.copy()
    
    for guess_count in range(6):
        guess = ''

        while not GUESS_RESTRICTION(guess):
            guess = input(f'{ORDINALS[guess_count]} guess: ')
            
            if len(words) == 1 and guess == next(iter(words)):
                print(f'Congratulations, you won in {guess_count + 1} turns!')
                return
            
        results = ''
        while not RESULTS_RESTRICTION(results):
            results = input('Result (ex. caace): ')
            
        exact, contains, absent = [], [], []

        for index, result in enumerate(results):
            letter = guess[index]
            if result == 'e':
                exact.append((index, letter))
            elif result == 'c':
                contains.append((index, letter))
            elif result == 'a':
                absent.append((index, letter))
                
        # print(f'Green letters: {exact}')
        # print(f'Yellow letters: {contains}')
        # print(f'Gray letters: {absent}')
        
        if len(exact) == 5 and guess in words:
            print(f'Congratulations, you won in {guess_count + 1} turns!')
            return
        elif len(exact) == 5:
            print(f'Invalid input, please restart.')
            return
        
        possible = set()
        for word in words:
            if satisfies(word, exact, contains, absent):
                possible.add(word)
                
        if len(possible) == 0:
            print(f'Invalid input, please restart.')
            return
        print(f'Possible words ({len(possible)}): {possible}\n')
        words = possible
        
    print('You lost :(')

# %%
solver(wordles, accepted_words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-2be6f0424759> in <module>
# ----> 1 solver(wordles, accepted_words)
#
# <ipython-input-24-5184acc11f1b> in solver(wordles, accepted_words)
#       6         guess = ''
#       7
# ----> 8         while not GUESS_RESTRICTION(guess):
#       9             guess = input(f'{ORDINALS[guess_count]} guess: ')
#      10
#
# NameError: name 'GUESS_RESTRICTION' is not defined

# %%
GREEN_STYLE = '\033[92m'
YELLOW_STYLE = '\033[33m'
GRAY_STYLE = '\033[30m'

def wordle_start():
    print('Welcome to Wordle!')
    response = ''
    while response.lower() not in ['0', '1', '2']:
        response = input('What assistance level would you like? (0/1/2): ')
        
    return int(response)

def play_main(wordles, accepted_words, wordle=None, assistance=None):
    if assistance is None:
        assistance = wordle_start()
        
    if wordle is None:
        wordle = random.choice(wordles)
        
    words = accepted_words.copy()
    wordle_print = ['\033[30m_'] * 5
    overall_exact_indices, overall_contains, overall_absent = set(), {}, set()
    guesses = []
    
    for guess_count in range(6):
        guess = ''

        while not GUESS_RESTRICTION(guess):
            guess = input(f'{ORDINALS[guess_count]} guess: ')
            
            if guess == wordle:
                print(f'Congratulations, you won in {guess_count + 1} turns!')
                return
        
        counts = Counter(wordle)
        exact, contains, absent = [], [], []
        colors = []
        indices = list(range(5))
        
        contains_counts = {}
        absent_set = set()
        
        # green handling
        i = 0
        while i < len(indices):
            index = indices[i]
            letter = guess[index]
            if wordle[index] == letter:
                exact.append((index, letter))
                counts[letter] -= 1
                indices.pop(i)
                
                overall_exact_indices.add(index)
                contains_counts[letter.upper()] = contains_counts[letter.upper()] + 1 if \
                    letter.upper() in contains_counts else 1
                
                stylized_letter = GREEN_STYLE + letter.upper()
                colors.append((index, stylized_letter))
                wordle_print[index] = stylized_letter
            else:
                i += 1
        
        # yellow handling
        i = 0
        while i < len(indices):
            index = indices[i]
            letter = guess[index]
            if letter in wordle and counts[letter] > 0:
                contains.append((index, letter))
                counts[letter] -= 1
                indices.pop(i)
                
                contains_counts[letter.upper()] = contains_counts[letter.upper()] + 1 if \
                    letter.upper() in contains_counts else 1
                
                stylized_letter = YELLOW_STYLE + letter.upper()
                colors.append((index, stylized_letter))
            else:
                i += 1

        # gray handling
        for index in indices:
            letter = guess[index]
            absent.append((index, letter))
            absent_set.add(letter.upper())
            
            stylized_letter = GRAY_STYLE + letter.upper()
            colors.append((index, stylized_letter))
        
        # printing basic assistance
        if assistance > 0:
            overall_exact = {}
            for idx in overall_exact_indices:
                letter = wordle[idx]
                overall_exact[letter.upper()] = overall_exact[letter.upper()] + 1 if \
                    letter.upper() in overall_exact else 1
                
            absent_set -= contains_counts.keys()
            absent_set -= overall_exact.keys()
            
            overall_contains = {key:max(overall_contains[key] if key in overall_contains else -np.inf,
                contains_counts[key] if key in contains_counts else -np.inf) for key in
                   set(list(overall_contains.keys())).union(contains_counts.keys())}
            
            overall_contains_copy = overall_contains.copy()
            for letter in overall_exact:
                if letter in overall_contains_copy:
                    overall_contains_copy[letter] -= overall_exact[letter]
                    if overall_contains_copy[letter] == 0:
                        del overall_contains_copy[letter]
            
            overall_absent = overall_absent.union(absent_set)
        
        guesses.append(''.join(map(lambda x: x[1], sorted(colors, key=lambda x: x[0]))))
        
        print('\033[1m')
        if assistance > 0:
            remaining = (set(ALPHABET.upper()) - overall_absent) - overall_contains.keys()
            print(f'{"".join(wordle_print)}\t{YELLOW_STYLE}Required: {overall_contains_copy}\t{GRAY_STYLE}Remaining: {sorted(remaining) if len(remaining) > 0 else "{}"}')
        for g in guesses:
            print(g)
        print('\033[0m')
        
        if assistance > 1:
            possible = set()
            for word in words:
                if satisfies(word, exact, contains, absent):
                    possible.add(word)

            print(f'Possible words ({len(possible)}): {possible}\n')
            words = possible
        
    print(f'You lost :(\nWordle: {wordle}')
    
def play(wordles, accepted_words):
    assistance = wordle_start()
    playagain = True
    while playagain:
        play_main(wordles, accepted_words, assistance=assistance)
        
        response = ''
        while response.lower() not in ['y', 'n', 'yes', 'no']:
            response = input('Would you like to play again? (y/n): ')

        playagain = (response.lower()[0] == 'y')
        print()

# %%
play(wordles, accepted_words)
# Out:
# Welcome to Wordle!
# What assistance level would you like? (0/1/2): 2
# 1st guess: raise
#
# _____	Required: {'I': 1}	Remaining: ['B', 'C', 'D', 'F', 'G', 'H', 'J', 'K', 'L', 'M', 'N', 'O', 'P', 'Q', 'T', 'U', 'V', 'W', 'X', 'Y', 'Z']
# RAISE
#
# Possible words (449): {'mingy', 'tumid', 'willy', 'tigon', 'biggy', 'duomi', 'picky', 'cibol', 'lotic', 'dicty', 'kinky', 'ninth', 'indol', 'pinko', 'licit', 'gippo', 'incog', 'humid', 'until', 'ictic', 'ninny', 'lipid', 'zinco', 'mucid', 'incut', 'witch', 'zilch', 'motif', 'yogin', 'zombi', 'pitch', 'villi', 'nihil', 'filmy', 'milky', 'mooli', 'ontic', 'tight', 'kindy', 'unfix', 'dicky', 'windy', "zymic'", 'kibbi', 'lindy', 'pilum', 'culti', 'pinup', 'wingy', 'input', 'bight', 'ticky', 'kimbo', 'tippy', 'finch', 'comix', 'titch', 'mitch', 'pubic', 'middy', 'kylix', 'mufti', 'bluid', 'livid', 'jingo', 'pudic', 'cinch', 'ogmic', 'piggy', 'bocci', 'pilow', 'bolix', 'picot', 'bidon', 'ovoli', 'zincy', 'picul', 'tutti', 'minty', 'widow', 'piccy', 'immit', 'bigot', 'fundi', 'oxlip', 'putid', 'linky', 'nifty', 'limit', 'ovoid', 'tilly', 'limby', 'zippy', 'ditch', 'lippy', 'mizzy', 'zimbi', 'dhobi', 'piony', 'pyoid', 'bovid', 'jimpy', 'illth', 'oggin', 'civil', 'ludic', 'kight', 'unkid', 'dight', 'binit', 'finny', 'cumin', 'licht', 'dinic', 'dippy', 'hilch', 'infix', 'inwit', 'humic', 'ohmic', 'pinky', 'fungi', 'qubit', 'bilgy', 'bimbo', 'dhuti', 'logic', 'wilco', 'mythi', 'pinch', 'cubit', 'bilbo', 'mincy', 'cinct', 'itchy', 'lungi', 'punji', 'cutin', 'litho', 'fixit', 'giddy', 'mixup', 'hinky', 'unbid', 'minim', 'polio', 'tinct', 'filmi', 'lupin', 'nimbi', 'gizmo', 'inbox', 'ninon', 'lichi', 'fichu', 'linin', 'timid', 'pippy', 'bingo', 'digit', 'zinky', 'dingo', 'conin', 'kiddo', 'uplit', 'kilim', 'tonic', 'oobit', 'undid', 'buffi', 'bilby', 'civic', 'unhip', 'fitly', 'diddy', 'yippy', 'gibli', 'vivid', 'jiffy', 'cunit', 'yogic', 'vinic', 'mucic', 'iodin', 'fifty', 'bijou', 'kitul', 'lingo', 'gobbi', 'kilty', 'combi', 'biffy', 'lytic', 'bizzy', 'ginny', 'myoid', 'linty', 'linum', 'gummi', 'tichy', 'niffy', 'linch', 'colin', 'ginch', 'conic', 'fifth', 'yomim', 'bindi', 'coxib', 'pinon', 'ciggy', 'kulfi', 'potin', 'viold', 'width', 'witty', 'tophi', 'tholi', 'choli', 'kitty', 'nooit', 'vigil', 'dicot', 'hinny', 'impot', 'might', 'login', 'zippo', 'lipin', 'iodid', 'kinin', 'covin', 'quoif', 'jimmy', 'pupil', 'gonif', 'mucin', 'dilly', 'timbo', 'likin', 'filth', 'tupik', 'tinty', 'dizzy', 'gilpy', 'jinni', 'pight', 'wongi', 'biccy', 'cylix', 'divvy', 'linux', 'hippo', 'untin', 'lucid', 'midgy', 'niton', 'zingy', 'bigly', 'zooid', 'nomic', 'pinny', 'hilly', 'immix', 'piton', 'hiply', 'cynic', 'fluid', 'oboli', 'tulip', 'pilch', 'tinny', 'gimpy', 'vomit', 'optic', 'titup', 'himbo', 'light', 'pulik', 'night', 'gipon', 'wight', 'jigot', 'quoit', 'powin', 'hikoi', 'hippy', 'comic', 'filly', 'ionic', 'pulli', 'mifty', 'quoin', 'pinto', 'bingy', 'coqui', 'pugil', 'ulmin', 'toxic', 'unlit', 'mochi', 'dixit', 'gitch', 'ootid', 'bitch', 'innit', 'nicht', 'vinyl', 'kiddy', 'fitch', 'mimic', 'imply', 'iodic', 'timon', 'folio', 'topoi', 'pipit', 'pipul', 'hilum', 'cubic', 'unfit', 'pilot', 'monic', 'dhoti', 'billy', 'ditzy', 'minny', 'gippy', 'bitou', 'pinot', 'hitch', 'ingot', 'cupid', 'hylic', 'zuzim', 'indow', 'dinky', 'biddy', 'unlid', 'kicky', 'dicht', 'domic', 'tondi', 'micht', 'bivvy', 'dilli', 'lumbi', 'wimpy', 'unmix', 'winch', 'milko', 'yonic', 'withy', 'dolci', 'oculi', 'nitty', 'fillo', 'pingo', 'typic', 'vichy', 'nomoi', 'unwit', 'miffy', 'hillo', 'modii', 'tunic', 'pitot', 'wiggy', 'fight', 'guqin', 'pithy', 'ditty', 'ginzo', 'bifid', 'thymi', 'fugio', 'fuzil', 'ippon', 'xylic', 'hight', 'gilly', 'igloo', 'colic', 'biont', 'globi', 'jiggy', 'dildo', 'logoi', 'tiyin', 'cippi', 'dimly', 'bipod', 'intil', 'pivot', 'unpin', 'tiddy', 'wifty', 'unzip', 'goyim', 'pigmy', 'dimbo', 'dingy', 'tilth', 'civvy', 'bodhi', 'bitty', 'oubit', 'kikoi', 'toxin', 'milty', 'ditto', 'nitid', 'limbi', 'idyll', 'miltz', 'biffo', 'lingy', 'putti', 'filii', 'widdy', 'milch', 'topic', 'limbo', 'fizzy', 'pikul', 'tizzy', 'hyoid', 'micky', 'gigot', 'divot', 'volti', 'nippy', 'linny', 'filch', 'hongi', 'cocci', 'zizit', 'bizzo', 'titty', 'mujik', 'ficin', 'gopik' ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-0608b49a5c8f> in <module>
# ----> 1 play(wordles, accepted_words)
#
# <ipython-input-30-5e00b0fc086d> in play(wordles, accepted_words)
#     137     playagain = True
#     138     while playagain:
# --> 139         play_main(wordles, accepted_words, assistance=assistance)
#     140
#     141         response = ''
#
# <ipython-input-30-5e00b0fc086d> in play_main(wordles, accepted_words, wordle, assistance)
#      27
#      28         while not GUESS_RESTRICTION(guess):
# ---> 29             guess = input(f'{ORDINALS[guess_count]} guess: ')
#      30
#      31             if guess == wordle:
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
